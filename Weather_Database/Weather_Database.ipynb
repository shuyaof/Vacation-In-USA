# %%
import timeit
import pandas as pd
import numpy as np
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lats,lngs)
coordinates=list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
import requests
from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
record_count=1
set_count=1

# %%
uri="http://api.openweathermap.org/data/2.5/weather?"
url=uri+"appid="+weather_api_key+"&units=Imperial"

# %%
# Loop through all the cities in the list.
city_data=[]
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 

        # Convert the date to ISO standard.
#city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(), 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=puerto+ayora
# Processing Record 1 of Set 1 | puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 86.68, 'temp_min': 77, 'temp_max': 77, 'pressure': 1009, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 336, 'gust': 3}, 'rain': {'1h': 0.36}, 'clouds': {'all': 22}, 'dt': 1616634382, 'sys': {'type': 3, 'id': 2005652, 'country': 'EC', 'sunrise': 1616587456, 'sunset': 1616631045}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=vaini
# Processing Record 2 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 78.62, 'feels_like': 73.31, 'temp_min': 78.62, 'temp_max': 78.62, 'pressure': 1010, 'humidity': 81, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 25.1, 'deg': 324, 'gust': 28.99}, 'rain': {'1h': 1.94}, 'clouds': {'all': 100}, 'dt': 1616634382, 'sys': {'country': 'TO', 'sunrise': 1616694371, 'sunset': 1616737610}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=ostrovnoy
# Processing Record 3 of Set 1 | ostrovnoy
# {'coord': {'lon': 39.5131, 'lat': 68.0531}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 33.87, 'feels_like': 19.4, 'temp_min': 33.87, 'temp_max': 33.87, 'pressure': 985, 'humidity': 85, 'sea_level': 985, 'grnd_level': 982}, 'visibility': 10000, 'wind': {'speed': 18.81, 'deg': 254, 'gust': 31.94}, 'clouds': {'all': 72}, 'dt': 1616634383, 'sys': {'country': 'RU', 'sunrise': 1616641231, 'sunset': 1616687710}, 'timezone': 10800, 'id': 556268, 'name': 'Ostrovnoy', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=guerrero+negro
# Processing Record 4 of Set 1 | guerrero negro
# {'coord': {'lon': -114.0611, 'lat': 27.9769}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 59.88, 'feels_like': 51.24, 'temp_min': 59.88, 'temp_max': 59.88, 'pressure': 1014, 'humidity': 66, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 14.79, 'deg': 328, 'gust': 15.99}, 'clouds': {'all': 0}, 'dt': 1616634205, 'sys': {'country': 'MX', 'sunrise': 1616592906, 'sunset': 1616636972}, 'timezone': -25200, 'id': 4021858, 'name': 'Guerrero Negro', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=labutta
# Processing Record 5 of Set 1 | labutta
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=viedma
# Processing Record 6 of Set 1 | viedma
# {'coord': {'lon': -62.9967, 'lat': -40.8135}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.89, 'feels_like': 52.75, 'temp_min': 60.89, 'temp_max': 60.89, 'pressure': 1020, 'humidity': 61, 'sea_level': 1020, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 13.35, 'deg': 123, 'gust': 18.54}, 'clouds': {'all': 100}, 'dt': 1616634383, 'sys': {'country': 'AR', 'sunrise': 1616581148, 'sunset': 1616624225}, 'timezone': -10800, 'id': 3832899, 'name': 'Viedma', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=jamestown
# Processing Record 7 of Set 1 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 57.87, 'feels_like': 51.22, 'temp_min': 54, 'temp_max': 60.01, 'pressure': 1011, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 171, 'gust': 28.66}, 'clouds': {'all': 20}, 'dt': 1616634215, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1616584370, 'sunset': 1616628796}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=rikitea
# Processing Record 8 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.45, 'feels_like': 78.96, 'temp_min': 79.45, 'temp_max': 79.45, 'pressure': 1017, 'humidity': 73, 'sea_level': 1017, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 14.43, 'deg': 96, 'gust': 15.73}, 'clouds': {'all': 10}, 'dt': 1616634136, 'sys': {'country': 'PF', 'sunrise': 1616598308, 'sunset': 1616641604}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=mar+del+plata
# Processing Record 9 of Set 1 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}, {'id': 502, 'main': 'Rain', 'description': 'heavy intensity rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 69.55, 'feels_like': 73.26, 'temp_min': 68, 'temp_max': 70, 'pressure': 1015, 'humidity': 88}, 'visibility': 600, 'wind': {'speed': 3.44, 'deg': 20}, 'rain': {'1h': 0.47}, 'clouds': {'all': 75}, 'dt': 1616634256, 'sys': {'type': 1, 'id': 8305, 'country': 'AR', 'sunrise': 1616579821, 'sunset': 1616622941}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=bluff
# Processing Record 10 of Set 1 | bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 63, 'feels_like': 62.83, 'temp_min': 63, 'temp_max': 63, 'pressure': 1020, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 52, 'gust': 5.99}, 'clouds': {'all': 11}, 'dt': 1616634383, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1616612104, 'sunset': 1616655017}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=ushuaia
# Processing Record 11 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 42.8, 'feels_like': 23.56, 'temp_min': 42.8, 'temp_max': 42.8, 'pressure': 1006, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 28.77, 'deg': 230}, 'clouds': {'all': 20}, 'dt': 1616634311, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1616582549, 'sunset': 1616625369}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=port+alfred
# Processing Record 12 of Set 1 | port alfred
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 68.5, 'feels_like': 64.56, 'temp_min': 68.5, 'temp_max': 68.5, 'pressure': 1015, 'humidity': 85, 'sea_level': 1015, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 15.48, 'deg': 68, 'gust': 23.69}, 'clouds': {'all': 100}, 'dt': 1616634384, 'sys': {'country': 'ZA', 'sunrise': 1616645957, 'sunset': 1616689041}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=nabire
# Processing Record 13 of Set 1 | nabire
# {'coord': {'lon': 135.4833, 'lat': -3.3667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.39, 'feels_like': 89.31, 'temp_min': 81.39, 'temp_max': 81.39, 'pressure': 1009, 'humidity': 75, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 2.01, 'deg': 206, 'gust': 3.42}, 'clouds': {'all': 100}, 'dt': 1616634384, 'sys': {'country': 'ID', 'sunrise': 1616619668, 'sunset': 1616663218}, 'timezone': 32400, 'id': 1634614, 'name': 'Nabire', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=kodiak
# Processing Record 14 of Set 1 | kodiak
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 44.6, 'feels_like': 36.9, 'temp_min': 44.6, 'temp_max': 44.6, 'pressure': 1020, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 210}, 'clouds': {'all': 75}, 'dt': 1616634138, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1616601531, 'sunset': 1616646750}, 'timezone': -28800, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=butaritari
# Processing Record 15 of Set 1 | butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 81.91, 'feels_like': 82.6, 'temp_min': 81.91, 'temp_max': 81.91, 'pressure': 1007, 'humidity': 79, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 16.91, 'deg': 85, 'gust': 20.33}, 'clouds': {'all': 25}, 'dt': 1616634384, 'sys': {'country': 'KI', 'sunrise': 1616610669, 'sunset': 1616654313}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=umzimvubu
# Processing Record 16 of Set 1 | umzimvubu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=coahuayana
# Processing Record 17 of Set 1 | coahuayana
# {'coord': {'lon': -103.6833, 'lat': 18.7333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 71.65, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1014, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 250}, 'clouds': {'all': 1}, 'dt': 1616634269, 'sys': {'type': 1, 'id': 7116, 'country': 'MX', 'sunrise': 1616590507, 'sunset': 1616634391}, 'timezone': -21600, 'id': 4013679, 'name': 'Coahuayana Viejo', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=lichinga
# Processing Record 18 of Set 1 | lichinga
# {'coord': {'lon': 35.2406, 'lat': -13.3128}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.2, 'feels_like': 64.62, 'temp_min': 64, 'temp_max': 64.4, 'pressure': 1019, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 90}, 'clouds': {'all': 75}, 'dt': 1616634384, 'sys': {'type': 1, 'id': 2203, 'country': 'MZ', 'sunrise': 1616643796, 'sunset': 1616687195}, 'timezone': 7200, 'id': 1043893, 'name': 'Lichinga', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=yellowknife
# Processing Record 19 of Set 1 | yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 7.81, 'feels_like': -3.91, 'temp_min': 7, 'temp_max': 8.6, 'pressure': 1017, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 70}, 'clouds': {'all': 1}, 'dt': 1616634385, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1616592229, 'sunset': 1616637789}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=jasper
# Processing Record 20 of Set 1 | jasper
# {'coord': {'lon': -94.3502, 'lat': 37.2001}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 51.39, 'feels_like': 45.09, 'temp_min': 51.01, 'temp_max': 52, 'pressure': 1011, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 40}, 'clouds': {'all': 1}, 'dt': 1616634385, 'sys': {'type': 1, 'id': 4590, 'country': 'US', 'sunrise': 1616588067, 'sunset': 1616632352}, 'timezone': -18000, 'id': 4392354, 'name': 'Jasper', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=grand+gaube
# Processing Record 21 of Set 1 | grand gaube
# {'coord': {'lon': 57.6608, 'lat': -20.0064}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 84.99, 'temp_min': 77, 'temp_max': 77, 'pressure': 1010, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 149, 'gust': 3}, 'clouds': {'all': 24}, 'dt': 1616634385, 'sys': {'type': 3, 'id': 2002134, 'country': 'MU', 'sunrise': 1616638464, 'sunset': 1616681768}, 'timezone': 14400, 'id': 934479, 'name': 'Grand Gaube', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=sakakah
# Processing Record 22 of Set 1 | sakakah
# {'coord': {'lon': 40.2064, 'lat': 29.9697}, 'weather': [{'id': 761, 'main': 'Dust', 'description': 'dust', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 60.8, 'feels_like': 48.63, 'temp_min': 60.8, 'temp_max': 60.8, 'pressure': 1014, 'humidity': 20}, 'visibility': 3500, 'wind': {'speed': 12.66, 'deg': 330}, 'clouds': {'all': 0}, 'dt': 1616634385, 'sys': {'type': 1, 'id': 7431, 'country': 'SA', 'sunrise': 1616642218, 'sunset': 1616686390}, 'timezone': 10800, 'id': 102527, 'name': 'Sakakah', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=tanout
# Processing Record 23 of Set 1 | tanout
# {'coord': {'lon': 8.8879, 'lat': 14.9709}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.97, 'feels_like': 64.33, 'temp_min': 75.97, 'temp_max': 75.97, 'pressure': 1010, 'humidity': 14, 'sea_level': 1010, 'grnd_level': 951}, 'visibility': 10000, 'wind': {'speed': 12.39, 'deg': 53, 'gust': 22.1}, 'clouds': {'all': 81}, 'dt': 1616634386, 'sys': {'country': 'NE', 'sunrise': 1616649892, 'sunset': 1616693746}, 'timezone': 3600, 'id': 2439155, 'name': 'Tanout', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=hobart
# Processing Record 24 of Set 1 | hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 62.37, 'feels_like': 60.62, 'temp_min': 61, 'temp_max': 64.4, 'pressure': 990, 'humidity': 82}, 'visibility': 7000, 'wind': {'speed': 6.91, 'deg': 310}, 'rain': {'1h': 0.21}, 'clouds': {'all': 75}, 'dt': 1616634386, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1616617114, 'sunset': 1616660086}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=bethel
# Processing Record 25 of Set 1 | bethel
# {'coord': {'lon': -73.414, 'lat': 41.3712}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 49.75, 'feels_like': 47.07, 'temp_min': 48.99, 'temp_max': 51.01, 'pressure': 1017, 'humidity': 94}, 'visibility': 7318, 'wind': {'speed': 4, 'deg': 96, 'gust': 10}, 'rain': {'1h': 0.84}, 'clouds': {'all': 100}, 'dt': 1616634217, 'sys': {'type': 3, 'id': 2004826, 'country': 'US', 'sunrise': 1616582986, 'sunset': 1616627386}, 'timezone': -14400, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=sabzevar
# Processing Record 26 of Set 1 | sabzevar
# {'coord': {'lon': 57.6819, 'lat': 36.2126}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 67.82, 'feels_like': 63.1, 'temp_min': 67.82, 'temp_max': 67.82, 'pressure': 1005, 'humidity': 33, 'sea_level': 1005, 'grnd_level': 898}, 'visibility': 10000, 'wind': {'speed': 3.67, 'deg': 249, 'gust': 5.44}, 'clouds': {'all': 100}, 'dt': 1616634386, 'sys': {'country': 'IR', 'sunrise': 1616637942, 'sunset': 1616682280}, 'timezone': 16200, 'id': 118063, 'name': 'Sabzawār', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=mys+shmidta
# Processing Record 27 of Set 1 | mys shmidta
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=nipawin
# Processing Record 28 of Set 1 | nipawin
# {'coord': {'lon': -104.0009, 'lat': 53.3668}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 32, 'feels_like': 19.06, 'temp_min': 32, 'temp_max': 32, 'pressure': 1007, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 100}, 'clouds': {'all': 90}, 'dt': 1616634386, 'sys': {'type': 1, 'id': 756, 'country': 'CA', 'sunrise': 1616590070, 'sunset': 1616634981}, 'timezone': -21600, 'id': 6088469, 'name': 'Nipawin', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=bredasdorp
# Processing Record 29 of Set 1 | bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 62.78, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1015, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 150}, 'clouds': {'all': 99}, 'dt': 1616634387, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1616647610, 'sunset': 1616690676}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=usinsk
# Processing Record 30 of Set 1 | usinsk
# {'coord': {'lon': 57.5281, 'lat': 65.9939}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 24.39, 'feels_like': 10.27, 'temp_min': 24.39, 'temp_max': 24.39, 'pressure': 995, 'humidity': 93, 'sea_level': 995, 'grnd_level': 987}, 'visibility': 10000, 'wind': {'speed': 16.64, 'deg': 185, 'gust': 28.57}, 'clouds': {'all': 100}, 'dt': 1616634387, 'sys': {'country': 'RU', 'sunrise': 1616637069, 'sunset': 1616683227}, 'timezone': 10800, 'id': 863061, 'name': 'Usinsk', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=ormara
# Processing Record 31 of Set 1 | ormara
# {'coord': {'lon': 64.6357, 'lat': 25.2088}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 75.02, 'feels_like': 74.84, 'temp_min': 75.02, 'temp_max': 75.02, 'pressure': 1014, 'humidity': 57, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 5.3, 'deg': 325, 'gust': 5.66}, 'clouds': {'all': 0}, 'dt': 1616634387, 'sys': {'country': 'PK', 'sunrise': 1616636416, 'sunset': 1616680469}, 'timezone': 18000, 'id': 1168700, 'name': 'Ormara', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=ribeira+grande
# Processing Record 32 of Set 1 | ribeira grande
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 56.97, 'feels_like': 53.69, 'temp_min': 56.97, 'temp_max': 56.97, 'pressure': 1029, 'humidity': 63, 'sea_level': 1029, 'grnd_level': 1029}, 'visibility': 10000, 'wind': {'speed': 3.53, 'deg': 39, 'gust': 4.21}, 'clouds': {'all': 20}, 'dt': 1616634203, 'sys': {'country': 'PT', 'sunrise': 1616658615, 'sunset': 1616703061}, 'timezone': -3600, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=busselton
# Processing Record 33 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 63, 'feels_like': 64.31, 'temp_min': 63, 'temp_max': 63, 'pressure': 1015, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 328, 'gust': 4}, 'clouds': {'all': 25}, 'dt': 1616634387, 'sys': {'type': 3, 'id': 2008303, 'country': 'AU', 'sunrise': 1616624721, 'sunset': 1616667835}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=jojoima
# Processing Record 34 of Set 1 | jojoima
# {'coord': {'lon': -10.7878, 'lat': 7.8792}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.07, 'feels_like': 82.58, 'temp_min': 75.07, 'temp_max': 75.07, 'pressure': 1012, 'humidity': 89, 'sea_level': 1012, 'grnd_level': 989}, 'visibility': 10000, 'wind': {'speed': 1.7, 'deg': 264, 'gust': 1.9}, 'clouds': {'all': 100}, 'dt': 1616634387, 'sys': {'country': 'SL', 'sunrise': 1616654676, 'sunset': 1616698405}, 'timezone': 0, 'id': 2408399, 'name': 'Jojoima', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=aloleng
# Processing Record 35 of Set 1 | aloleng
# {'coord': {'lon': 119.7824, 'lat': 16.1307}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.53, 'feels_like': 86.97, 'temp_min': 83.53, 'temp_max': 83.53, 'pressure': 1013, 'humidity': 62, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 6.67, 'deg': 62, 'gust': 8.14}, 'clouds': {'all': 98}, 'dt': 1616634388, 'sys': {'country': 'PH', 'sunrise': 1616623280, 'sunset': 1616667140}, 'timezone': 28800, 'id': 1731298, 'name': 'Aloleng', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=amderma
# Processing Record 36 of Set 1 | amderma
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=east+london
# Processing Record 37 of Set 1 | east london
# {'coord': {'lon': 27.9116, 'lat': -33.0153}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 68.05, 'feels_like': 66.78, 'temp_min': 68.05, 'temp_max': 68.05, 'pressure': 1015, 'humidity': 86, 'sea_level': 1015, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 10.67, 'deg': 54, 'gust': 18.68}, 'rain': {'1h': 0.3}, 'clouds': {'all': 100}, 'dt': 1616634161, 'sys': {'country': 'ZA', 'sunrise': 1616645707, 'sunset': 1616688802}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=carnarvon
# Processing Record 38 of Set 1 | carnarvon
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 71.17, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1010, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 190}, 'clouds': {'all': 21}, 'dt': 1616634388, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1616625063, 'sunset': 1616668309}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=marzuq
# Processing Record 39 of Set 1 | marzuq
# {'coord': {'lon': 46.4667, 'lat': 14.4}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.49, 'feels_like': 57.33, 'temp_min': 64.49, 'temp_max': 64.49, 'pressure': 1013, 'humidity': 24, 'sea_level': 1013, 'grnd_level': 887}, 'visibility': 10000, 'wind': {'speed': 5.17, 'deg': 193, 'gust': 4.94}, 'clouds': {'all': 0}, 'dt': 1616634388, 'sys': {'country': 'YE', 'sunrise': 1616640883, 'sunset': 1616684721}, 'timezone': 10800, 'id': 72181, 'name': 'Marzuq', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=bahia+blanca
# Processing Record 40 of Set 1 | bahia blanca
# {'coord': {'lon': -62.2724, 'lat': -38.7196}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 63.95, 'feels_like': 56.05, 'temp_min': 63.95, 'temp_max': 63.95, 'pressure': 1017, 'humidity': 66, 'sea_level': 1017, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 15.35, 'deg': 133, 'gust': 23.8}, 'clouds': {'all': 100}, 'dt': 1616634199, 'sys': {'country': 'AR', 'sunrise': 1616580959, 'sunset': 1616624066}, 'timezone': -10800, 'id': 3865086, 'name': 'Bahía Blanca', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=pisco
# Processing Record 41 of Set 1 | pisco
# {'coord': {'lon': -76.2167, 'lat': -13.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 68, 'feels_like': 63.88, 'temp_min': 68, 'temp_max': 68, 'pressure': 1012, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 210}, 'clouds': {'all': 0}, 'dt': 1616634195, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1616584146, 'sunset': 1616627571}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=victoria
# Processing Record 42 of Set 1 | victoria
# {'coord': {'lon': 114.1577, 'lat': 22.2855}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 67.78, 'feels_like': 62.6, 'temp_min': 59, 'temp_max': 71.01, 'pressure': 1019, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 14, 'deg': 86, 'gust': 14.97}, 'clouds': {'all': 95}, 'dt': 1616634389, 'sys': {'type': 3, 'id': 2035800, 'country': 'HK', 'sunrise': 1616624570, 'sunset': 1616668549}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=priiskovyy
# Processing Record 43 of Set 1 | priiskovyy
# {'coord': {'lon': 116.6333, 'lat': 51.9333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 29.32, 'feels_like': 23.16, 'temp_min': 29.32, 'temp_max': 29.32, 'pressure': 1019, 'humidity': 89, 'sea_level': 1019, 'grnd_level': 955}, 'visibility': 10000, 'wind': {'speed': 3.29, 'deg': 250, 'gust': 4.27}, 'clouds': {'all': 73}, 'dt': 1616634389, 'sys': {'country': 'RU', 'sunrise': 1616623501, 'sunset': 1616668431}, 'timezone': 32400, 'id': 2017632, 'name': 'Priiskovyy', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=calvinia
# Processing Record 44 of Set 1 | calvinia
# {'coord': {'lon': 19.776, 'lat': -31.4707}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 67.44, 'feels_like': 65.08, 'temp_min': 67.44, 'temp_max': 67.44, 'pressure': 1013, 'humidity': 47, 'sea_level': 1013, 'grnd_level': 904}, 'visibility': 10000, 'wind': {'speed': 2.75, 'deg': 269, 'gust': 2.95}, 'clouds': {'all': 0}, 'dt': 1616634389, 'sys': {'country': 'ZA', 'sunrise': 1616647648, 'sunset': 1616690765}, 'timezone': 7200, 'id': 3369174, 'name': 'Calvinia', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=nikolskoye
# Processing Record 45 of Set 1 | nikolskoye
# {'coord': {'lon': 30.7861, 'lat': 59.7035}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 37.15, 'feels_like': 28.51, 'temp_min': 36, 'temp_max': 37.99, 'pressure': 1011, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 8.95, 'deg': 230}, 'clouds': {'all': 90}, 'dt': 1616634159, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1616643804, 'sunset': 1616689325}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=arraial+do+cabo
# Processing Record 46 of Set 1 | arraial do cabo
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 83.86, 'temp_min': 77, 'temp_max': 77, 'pressure': 1016, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 4.36, 'deg': 62, 'gust': 4.68}, 'clouds': {'all': 0}, 'dt': 1616634389, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1616575996, 'sunset': 1616619314}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=georgetown
# Processing Record 47 of Set 1 | georgetown
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 78.21, 'feels_like': 86.13, 'temp_min': 77, 'temp_max': 80.01, 'pressure': 1008, 'humidity': 94}, 'visibility': 2000, 'wind': {'speed': 5.75, 'deg': 70}, 'clouds': {'all': 20}, 'dt': 1616634390, 'sys': {'type': 1, 'id': 9429, 'country': 'MY', 'sunrise': 1616628036, 'sunset': 1616671717}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=geraldton
# Processing Record 48 of Set 1 | geraldton
# {'coord': {'lon': 114.6, 'lat': -28.7667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 69.8, 'feels_like': 63.12, 'temp_min': 69.8, 'temp_max': 69.8, 'pressure': 1011, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 150}, 'clouds': {'all': 0}, 'dt': 1616634390, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1616624859, 'sunset': 1616668048}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=margate
# Processing Record 49 of Set 1 | margate
# {'coord': {'lon': 1.3862, 'lat': 51.3813}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 47.3, 'feels_like': 44.6, 'temp_min': 46.99, 'temp_max': 48, 'pressure': 1003, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 149, 'gust': 4}, 'clouds': {'all': 100}, 'dt': 1616634390, 'sys': {'type': 3, 'id': 2020742, 'country': 'GB', 'sunrise': 1616651131, 'sunset': 1616696107}, 'timezone': 0, 'id': 2643044, 'name': 'Margate', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=lompoc
# Processing Record 50 of Set 1 | lompoc
# {'coord': {'lon': -120.4579, 'lat': 34.6391}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 57.6, 'feels_like': 49.21, 'temp_min': 54, 'temp_max': 60.8, 'pressure': 1014, 'humidity': 55}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 270}, 'clouds': {'all': 20}, 'dt': 1616634391, 'sys': {'type': 1, 'id': 4747, 'country': 'US', 'sunrise': 1616594361, 'sunset': 1616638587}, 'timezone': -25200, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=jizan
# Processing Record 1 of Set 2 | jizan
# {'coord': {'lon': 42.6667, 'lat': 17.3333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 83.95, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1007, 'humidity': 54}, 'visibility': 9000, 'wind': {'speed': 1.5, 'deg': 305, 'gust': 2.53}, 'clouds': {'all': 3}, 'dt': 1616634391, 'sys': {'type': 1, 'id': 7407, 'country': 'SA', 'sunrise': 1616641767, 'sunset': 1616685661}, 'timezone': 10800, 'id': 105298, 'name': 'Jizan', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=punta+arenas
# Processing Record 2 of Set 2 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 48.09, 'feels_like': 33.4, 'temp_min': 48, 'temp_max': 48.2, 'pressure': 1011, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 21.85, 'deg': 260}, 'clouds': {'all': 40}, 'dt': 1616634115, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1616583160, 'sunset': 1616626014}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=balabac
# Processing Record 3 of Set 2 | balabac
# {'coord': {'lon': 117.0645, 'lat': 7.9868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.24, 'feels_like': 84.58, 'temp_min': 82.24, 'temp_max': 82.24, 'pressure': 1010, 'humidity': 80, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 14.67, 'deg': 64, 'gust': 18.99}, 'clouds': {'all': 100}, 'dt': 1616634391, 'sys': {'country': 'PH', 'sunrise': 1616624002, 'sunset': 1616667723}, 'timezone': 28800, 'id': 1728675, 'name': 'Balabac', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=vila
# Processing Record 4 of Set 2 | vila
# {'coord': {'lon': -8.1588, 'lat': 42.0304}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 42.01, 'feels_like': 38.43, 'temp_min': 42.01, 'temp_max': 42.01, 'pressure': 1027, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 18, 'gust': 3}, 'clouds': {'all': 100}, 'dt': 1616634391, 'sys': {'type': 3, 'id': 2007751, 'country': 'PT', 'sunrise': 1616653629, 'sunset': 1616698190}, 'timezone': 0, 'id': 7117100, 'name': 'Vila', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=constitucion
# Processing Record 5 of Set 2 | constitucion
# {'coord': {'lon': -72.4167, 'lat': -35.3333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 53.83, 'feels_like': 45.34, 'temp_min': 53.83, 'temp_max': 53.83, 'pressure': 1018, 'humidity': 83, 'sea_level': 1018, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 14.67, 'deg': 207, 'gust': 19.75}, 'clouds': {'all': 67}, 'dt': 1616634392, 'sys': {'country': 'CL', 'sunrise': 1616583371, 'sunset': 1616626522}, 'timezone': -10800, 'id': 3893726, 'name': 'Constitución', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=saint-joseph
# Processing Record 6 of Set 2 | saint-joseph
# {'coord': {'lon': 55.6167, 'lat': -21.3667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 76.48, 'feels_like': 78.85, 'temp_min': 75.99, 'temp_max': 77, 'pressure': 1008, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 40}, 'clouds': {'all': 0}, 'dt': 1616634392, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1616638965, 'sunset': 1616682249}, 'timezone': 14400, 'id': 6690296, 'name': 'Saint-Joseph', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=austin
# Processing Record 7 of Set 2 | austin
# {'coord': {'lon': -97.7431, 'lat': 30.2672}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 67.15, 'feels_like': 69.21, 'temp_min': 66, 'temp_max': 69.01, 'pressure': 1004, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 110}, 'clouds': {'all': 90}, 'dt': 1616634124, 'sys': {'type': 1, 'id': 3344, 'country': 'US', 'sunrise': 1616588968, 'sunset': 1616633080}, 'timezone': -18000, 'id': 4671654, 'name': 'Austin', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=manbij
# Processing Record 8 of Set 2 | manbij
# {'coord': {'lon': 37.9549, 'lat': 36.5281}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 30.87, 'temp_min': 41, 'temp_max': 41, 'pressure': 1002, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 210}, 'clouds': {'all': 40}, 'dt': 1616634392, 'sys': {'type': 1, 'id': 6952, 'country': 'SY', 'sunrise': 1616642667, 'sunset': 1616687022}, 'timezone': 7200, 'id': 167357, 'name': 'Manbij', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=zatoka
# Processing Record 9 of Set 2 | zatoka
# {'coord': {'lon': 30.4654, 'lat': 46.0725}, 'weather': [{'id': 615, 'main': 'Snow', 'description': 'light rain and snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 33.4, 'feels_like': 25, 'temp_min': 33.01, 'temp_max': 33.8, 'pressure': 1014, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 8.95, 'deg': 350}, 'snow': {'1h': 0.21}, 'clouds': {'all': 90}, 'dt': 1616634392, 'sys': {'type': 1, 'id': 8915, 'country': 'UA', 'sunrise': 1616644290, 'sunset': 1616688993}, 'timezone': 7200, 'id': 687557, 'name': 'Zatoka', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=hermanus
# Processing Record 10 of Set 2 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 68, 'feels_like': 68.79, 'temp_min': 68, 'temp_max': 68, 'pressure': 1013, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 111, 'gust': 15.99}, 'clouds': {'all': 0}, 'dt': 1616634393, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1616647803, 'sunset': 1616690870}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=port+blair
# Processing Record 11 of Set 2 | port blair
# {'coord': {'lon': 92.75, 'lat': 11.6667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 82.33, 'feels_like': 88.2, 'temp_min': 82.33, 'temp_max': 82.33, 'pressure': 1010, 'humidity': 76, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 25, 'gust': 8.81}, 'clouds': {'all': 35}, 'dt': 1616634148, 'sys': {'country': 'IN', 'sunrise': 1616629804, 'sunset': 1616673589}, 'timezone': 19800, 'id': 1259385, 'name': 'Port Blair', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=cidreira
# Processing Record 12 of Set 2 | cidreira
# {'coord': {'lon': -50.2056, 'lat': -30.1811}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 73.29, 'feels_like': 73.27, 'temp_min': 73.29, 'temp_max': 73.29, 'pressure': 1018, 'humidity': 78, 'sea_level': 1018, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 10.22, 'deg': 72, 'gust': 15.79}, 'clouds': {'all': 3}, 'dt': 1616634189, 'sys': {'country': 'BR', 'sunrise': 1616578004, 'sunset': 1616621231}, 'timezone': -10800, 'id': 3466165, 'name': 'Cidreira', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=muros
# Processing Record 13 of Set 2 | muros
# {'coord': {'lon': -9.0603, 'lat': 42.7762}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 43.11, 'feels_like': 38.19, 'temp_min': 41, 'temp_max': 44.01, 'pressure': 1029, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 58, 'gust': 5.48}, 'clouds': {'all': 95}, 'dt': 1616634393, 'sys': {'type': 3, 'id': 2000018, 'country': 'ES', 'sunrise': 1616653831, 'sunset': 1616698420}, 'timezone': 3600, 'id': 3115824, 'name': 'Muros', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=cayenne
# Processing Record 14 of Set 2 | cayenne
# {'coord': {'lon': -52.3333, 'lat': 4.9333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 78.53, 'feels_like': 88.57, 'temp_min': 75.2, 'temp_max': 81, 'pressure': 1014, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 250}, 'clouds': {'all': 20}, 'dt': 1616634393, 'sys': {'type': 1, 'id': 8669, 'country': 'GF', 'sunrise': 1616578295, 'sunset': 1616621960}, 'timezone': -10800, 'id': 3382160, 'name': 'Cayenne', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=belmonte
# Processing Record 15 of Set 2 | belmonte
# {'coord': {'lon': -38.8828, 'lat': -15.8631}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 80.94, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1016, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 80}, 'clouds': {'all': 0}, 'dt': 1616634393, 'sys': {'type': 1, 'id': 8422, 'country': 'BR', 'sunrise': 1616575198, 'sunset': 1616618602}, 'timezone': -10800, 'id': 3470137, 'name': 'Belmonte', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=albany
# Processing Record 16 of Set 2 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 51.17, 'feels_like': 49.24, 'temp_min': 50, 'temp_max': 52, 'pressure': 1014, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 166, 'gust': 8.99}, 'clouds': {'all': 100}, 'dt': 1616634394, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1616583099, 'sunset': 1616627538}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=mitsamiouli
# Processing Record 17 of Set 2 | mitsamiouli
# {'coord': {'lon': 43.2844, 'lat': -11.3847}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 82.27, 'feels_like': 89.37, 'temp_min': 82.27, 'temp_max': 82.27, 'pressure': 1008, 'humidity': 71, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 2.71, 'deg': 178, 'gust': 2.48}, 'clouds': {'all': 5}, 'dt': 1616634394, 'sys': {'country': 'KM', 'sunrise': 1616641852, 'sunset': 1616685280}, 'timezone': 10800, 'id': 921786, 'name': 'Mitsamiouli', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=christchurch
# Processing Record 18 of Set 2 | christchurch
# {'coord': {'lon': 172.6333, 'lat': -43.5333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 65.28, 'feels_like': 56.3, 'temp_min': 64, 'temp_max': 66.2, 'pressure': 1021, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 80}, 'clouds': {'all': 20}, 'dt': 1616634327, 'sys': {'type': 1, 'id': 7348, 'country': 'NZ', 'sunrise': 1616611042, 'sunset': 1616654015}, 'timezone': 46800, 'id': 2192362, 'name': 'Christchurch', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=kichera
# Processing Record 19 of Set 2 | kichera
# {'coord': {'lon': 110.0997, 'lat': 55.9375}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 23.74, 'feels_like': 15.55, 'temp_min': 23.74, 'temp_max': 23.74, 'pressure': 1018, 'humidity': 81, 'sea_level': 1018, 'grnd_level': 958}, 'visibility': 10000, 'wind': {'speed': 5.46, 'deg': 56, 'gust': 8.41}, 'clouds': {'all': 100}, 'dt': 1616634394, 'sys': {'country': 'RU', 'sunrise': 1616624947, 'sunset': 1616670120}, 'timezone': 28800, 'id': 2022129, 'name': 'Kichera', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=klaksvik
# Processing Record 20 of Set 2 | klaksvik
# {'coord': {'lon': -6.589, 'lat': 62.2266}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 39.2, 'feels_like': 34.9, 'temp_min': 39.2, 'temp_max': 39.2, 'pressure': 997, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 240}, 'clouds': {'all': 16}, 'dt': 1616634394, 'sys': {'type': 1, 'id': 1596, 'country': 'FO', 'sunrise': 1616652637, 'sunset': 1616698429}, 'timezone': 0, 'id': 2618795, 'name': 'Klaksvík', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=sorland
# Processing Record 21 of Set 2 | sorland
# {'coord': {'lon': 12.6934, 'lat': 67.667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 37.15, 'feels_like': 24.31, 'temp_min': 37.15, 'temp_max': 37.15, 'pressure': 994, 'humidity': 81, 'sea_level': 994, 'grnd_level': 992}, 'visibility': 4606, 'wind': {'speed': 16.4, 'deg': 272, 'gust': 18.54}, 'rain': {'1h': 0.12919999999999998}, 'clouds': {'all': 100}, 'dt': 1616634395, 'sys': {'country': 'NO', 'sunrise': 1616647679, 'sunset': 1616694132}, 'timezone': 3600, 'id': 3137469, 'name': 'Sørland', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=ust-tsilma
# Processing Record 22 of Set 2 | ust-tsilma
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=spremberg
# Processing Record 36 of Set 15 | spremberg
# {'coord': {'lon': 14.3736, 'lat': 51.5697}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 36.39, 'feels_like': 30.33, 'temp_min': 35.01, 'temp_max': 37.99, 'pressure': 1020, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 5.19, 'deg': 220, 'gust': 5.88}, 'clouds': {'all': 14}, 'dt': 1616634511, 'sys': {'type': 3, 'id': 2035260, 'country': 'DE', 'sunrise': 1616648013, 'sunset': 1616692992}, 'timezone': 3600, 'id': 6550659, 'name': 'Spremberg', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=sawakin
# Processing Record 37 of Set 15 | sawakin
# {'coord': {'lon': 37.3321, 'lat': 19.1059}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.77, 'feels_like': 74.44, 'temp_min': 76.77, 'temp_max': 76.77, 'pressure': 1008, 'humidity': 82, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 18.45, 'deg': 0, 'gust': 21.41}, 'clouds': {'all': 67}, 'dt': 1616634511, 'sys': {'country': 'SD', 'sunrise': 1616643029, 'sunset': 1616686959}, 'timezone': 7200, 'id': 367544, 'name': 'Sawākin', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=kasama
# Processing Record 38 of Set 15 | kasama
# {'coord': {'lon': 31.1808, 'lat': -10.2129}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.76, 'feels_like': 60.91, 'temp_min': 59.76, 'temp_max': 59.76, 'pressure': 1012, 'humidity': 98, 'sea_level': 1012, 'grnd_level': 861}, 'visibility': 10000, 'wind': {'speed': 3.24, 'deg': 106, 'gust': 9.46}, 'clouds': {'all': 66}, 'dt': 1616634512, 'sys': {'country': 'ZM', 'sunrise': 1616644748, 'sunset': 1616688192}, 'timezone': 7200, 'id': 912764, 'name': 'Kasama', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=kautokeino
# Processing Record 39 of Set 15 | kautokeino
# {'coord': {'lon': 23.0412, 'lat': 69.0125}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 35.15, 'feels_like': 14.63, 'temp_min': 35.15, 'temp_max': 35.15, 'pressure': 977, 'humidity': 78, 'sea_level': 977, 'grnd_level': 939}, 'visibility': 10000, 'wind': {'speed': 29.35, 'deg': 265, 'gust': 45.25}, 'clouds': {'all': 47}, 'dt': 1616634512, 'sys': {'country': 'NO', 'sunrise': 1616645093, 'sunset': 1616691753}, 'timezone': 3600, 'id': 779330, 'name': 'Kautokeino', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=hovd
# Processing Record 40 of Set 15 | hovd
# {'coord': {'lon': 91.6419, 'lat': 48.0056}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 29.93, 'feels_like': 20.48, 'temp_min': 29.93, 'temp_max': 29.93, 'pressure': 1021, 'humidity': 22, 'sea_level': 1021, 'grnd_level': 860}, 'visibility': 10000, 'wind': {'speed': 5.3, 'deg': 235, 'gust': 5.86}, 'clouds': {'all': 61}, 'dt': 1616634512, 'sys': {'country': 'MN', 'sunrise': 1616629586, 'sunset': 1616674339}, 'timezone': 25200, 'id': 1516048, 'name': 'Khovd', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=atherton
# Processing Record 41 of Set 15 | atherton
# {'coord': {'lon': -2.4935, 'lat': 53.5237}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 45.84, 'feels_like': 41.88, 'temp_min': 44.01, 'temp_max': 46.99, 'pressure': 1016, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 135, 'gust': 3}, 'clouds': {'all': 100}, 'dt': 1616634512, 'sys': {'type': 3, 'id': 2001932, 'country': 'GB', 'sunrise': 1616651998, 'sunset': 1616697102}, 'timezone': 0, 'id': 2656847, 'name': 'Atherton', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=kashary
# Processing Record 42 of Set 15 | kashary
# {'coord': {'lon': 41.0056, 'lat': 49.04}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 32.86, 'feels_like': 22.39, 'temp_min': 32.86, 'temp_max': 32.86, 'pressure': 1009, 'humidity': 98, 'sea_level': 1009, 'grnd_level': 998}, 'visibility': 37, 'wind': {'speed': 12.35, 'deg': 37, 'gust': 27.63}, 'snow': {'1h': 1.332}, 'clouds': {'all': 100}, 'dt': 1616634513, 'sys': {'country': 'RU', 'sunrise': 1616641697, 'sunset': 1616686528}, 'timezone': 10800, 'id': 552006, 'name': 'Kashary', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=kafue
# Processing Record 43 of Set 15 | kafue
# {'coord': {'lon': 28.1814, 'lat': -15.7691}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 61.16, 'feels_like': 62.11, 'temp_min': 61.16, 'temp_max': 61.16, 'pressure': 1013, 'humidity': 96, 'sea_level': 1013, 'grnd_level': 902}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 78, 'gust': 10.29}, 'clouds': {'all': 0}, 'dt': 1616634513, 'sys': {'country': 'ZM', 'sunrise': 1616645509, 'sunset': 1616688870}, 'timezone': 7200, 'id': 915883, 'name': 'Kafue', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=mogadishu
# Processing Record 44 of Set 15 | mogadishu
# {'coord': {'lon': 45.3438, 'lat': 2.0371}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 77.76, 'feels_like': 78.19, 'temp_min': 77.76, 'temp_max': 77.76, 'pressure': 1009, 'humidity': 78, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 13.09, 'deg': 77, 'gust': 16.46}, 'clouds': {'all': 2}, 'dt': 1616634509, 'sys': {'country': 'SO', 'sunrise': 1616641256, 'sunset': 1616684887}, 'timezone': 10800, 'id': 53654, 'name': 'Mogadishu', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=columbus
# Processing Record 45 of Set 15 | columbus
# {'coord': {'lon': -82.9988, 'lat': 39.9612}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 65.16, 'feels_like': 58.78, 'temp_min': 62.6, 'temp_max': 66.99, 'pressure': 1011, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 200}, 'clouds': {'all': 40}, 'dt': 1616634371, 'sys': {'type': 1, 'id': 3656, 'country': 'US', 'sunrise': 1616585306, 'sunset': 1616629666}, 'timezone': -14400, 'id': 4509177, 'name': 'Columbus', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=sovetskiy
# Processing Record 46 of Set 15 | sovetskiy
# {'coord': {'lon': 63.5842, 'lat': 61.3614}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 13.37, 'feels_like': 5, 'temp_min': 13.37, 'temp_max': 13.37, 'pressure': 1006, 'humidity': 96, 'sea_level': 1006, 'grnd_level': 991}, 'visibility': 10000, 'wind': {'speed': 4.9, 'deg': 276, 'gust': 14.94}, 'clouds': {'all': 24}, 'dt': 1616634513, 'sys': {'country': 'RU', 'sunrise': 1616635876, 'sunset': 1616681514}, 'timezone': 18000, 'id': 1491230, 'name': 'Sovetskiy', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=milkovo
# Processing Record 47 of Set 15 | milkovo
# {'coord': {'lon': 158.6167, 'lat': 54.7167}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 26.58, 'feels_like': 11.44, 'temp_min': 26.58, 'temp_max': 26.58, 'pressure': 1012, 'humidity': 61, 'sea_level': 1012, 'grnd_level': 991}, 'visibility': 10000, 'wind': {'speed': 17.22, 'deg': 223, 'gust': 37.85}, 'clouds': {'all': 70}, 'dt': 1616634513, 'sys': {'country': 'RU', 'sunrise': 1616613363, 'sunset': 1616658421}, 'timezone': 43200, 'id': 2123278, 'name': "Mil'kovo", 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=itapecerica
# Processing Record 48 of Set 15 | itapecerica
# {'coord': {'lon': -45.1256, 'lat': -20.4725}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 69.39, 'feels_like': 72.12, 'temp_min': 69.39, 'temp_max': 69.39, 'pressure': 1016, 'humidity': 83, 'sea_level': 1016, 'grnd_level': 924}, 'visibility': 10000, 'wind': {'speed': 3.78, 'deg': 146, 'gust': 3.85}, 'clouds': {'all': 98}, 'dt': 1616634514, 'sys': {'country': 'BR', 'sunrise': 1616576724, 'sunset': 1616620072}, 'timezone': -10800, 'id': 3460752, 'name': 'Itapecerica', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=ranong
# Processing Record 49 of Set 15 | ranong
# {'coord': {'lon': 98.6348, 'lat': 9.9658}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 83.97, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1009, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 1.14, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1616634514, 'sys': {'type': 1, 'id': 9269, 'country': 'TH', 'sunrise': 1616628407, 'sunset': 1616672162}, 'timezone': 25200, 'id': 1150965, 'name': 'Ranong', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=pucallpa
# Processing Record 50 of Set 15 | pucallpa
# {'coord': {'lon': -74.5539, 'lat': -8.3791}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 86.14, 'temp_min': 77, 'temp_max': 77, 'pressure': 1011, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 320}, 'clouds': {'all': 40}, 'dt': 1616634267, 'sys': {'type': 1, 'id': 8675, 'country': 'PE', 'sunrise': 1616583714, 'sunset': 1616627205}, 'timezone': -18000, 'id': 3693345, 'name': 'Pucallpa', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=yankton
# Processing Record 1 of Set 16 | yankton
# {'coord': {'lon': -97.3973, 'lat': 42.8711}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 43.81, 'feels_like': 38.19, 'temp_min': 42.8, 'temp_max': 45, 'pressure': 1012, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 330}, 'clouds': {'all': 1}, 'dt': 1616634514, 'sys': {'type': 1, 'id': 6329, 'country': 'US', 'sunrise': 1616588711, 'sunset': 1616633171}, 'timezone': -18000, 'id': 5233053, 'name': 'Yankton', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=roald
# Processing Record 2 of Set 16 | roald
# {'coord': {'lon': 6.1333, 'lat': 62.5833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 41.7, 'feels_like': 31.48, 'temp_min': 39.99, 'temp_max': 42.8, 'pressure': 1002, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 190}, 'clouds': {'all': 75}, 'dt': 1616634514, 'sys': {'type': 1, 'id': 1602, 'country': 'NO', 'sunrise': 1616649572, 'sunset': 1616695388}, 'timezone': 3600, 'id': 3141667, 'name': 'Roald', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=bereda
# Processing Record 3 of Set 16 | bereda
# {'coord': {'lon': -7.5406, 'lat': 43.2686}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 38.23, 'feels_like': 34.5, 'temp_min': 34, 'temp_max': 43, 'pressure': 1026, 'humidity': 99}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 158, 'gust': 3}, 'clouds': {'all': 84}, 'dt': 1616634515, 'sys': {'type': 3, 'id': 2013071, 'country': 'ES', 'sunrise': 1616653457, 'sunset': 1616698065}, 'timezone': 3600, 'id': 3105522, 'name': 'Bereda', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=kadi
# Processing Record 4 of Set 16 | kadi
# {'coord': {'lon': 72.3333, 'lat': 23.3}, 'weather': [{'id': 711, 'main': 'Smoke', 'description': 'smoke', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 68, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1012, 'humidity': 22}, 'visibility': 4000, 'wind': {'speed': 6.91, 'deg': 50}, 'clouds': {'all': 5}, 'dt': 1616634515, 'sys': {'type': 1, 'id': 9049, 'country': 'IN', 'sunrise': 1616634591, 'sunset': 1616678600}, 'timezone': 19800, 'id': 1268680, 'name': 'Kadi', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=kholmogory
# Processing Record 5 of Set 16 | kholmogory
# {'coord': {'lon': 41.656, 'lat': 64.2229}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 39.2, 'feels_like': 29.32, 'temp_min': 39.2, 'temp_max': 39.2, 'pressure': 995, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 11.18, 'deg': 270}, 'clouds': {'all': 20}, 'dt': 1616634515, 'sys': {'type': 1, 'id': 8922, 'country': 'RU', 'sunrise': 1616640977, 'sunset': 1616686935}, 'timezone': 10800, 'id': 549748, 'name': 'Kholmogory', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=malkara
# Processing Record 6 of Set 16 | malkara
# {'coord': {'lon': 26.9011, 'lat': 40.89}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 26.17, 'feels_like': 18.09, 'temp_min': 26.17, 'temp_max': 26.17, 'pressure': 1018, 'humidity': 86, 'sea_level': 1018, 'grnd_level': 983}, 'visibility': 10000, 'wind': {'speed': 5.93, 'deg': 357, 'gust': 15.86}, 'clouds': {'all': 12}, 'dt': 1616634515, 'sys': {'country': 'TR', 'sunrise': 1616645245, 'sunset': 1616689748}, 'timezone': 10800, 'id': 741771, 'name': 'Malkara', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?appid=33885d8741c8f73b5f81237773bef73a&units=Imperial&q=phan+thiet
# Processing Record 7 of Set 16 | phan thiet
# {'coord': {'lon': 108.1, 'lat': 10.9333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.22, 'feels_like': 84.74, 'temp_min': 82.22, 'temp_max': 82.22, 'pressure': 1012, 'humidity': 66, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 8.81, 'deg': 62, 'gust': 12.59}, 'clouds': {'all': 100}, 'dt': 1616634516, 'sys': {'country': 'VN', 'sunrise': 1616626128, 'sunset': 1616669899}, 'timezone': 25200, 'id': 1571058, 'name': 'Phan Thiet', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
city_data_df=pd.DataFrame(city_data)

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0      Puerto Ayora      EC  -0.7393  -90.3518     77.00        93
# 1             Vaini      TO -21.2000 -175.2000     78.62        81
# 2         Ostrovnoy      RU  68.0531   39.5131     33.87        85
# 3    Guerrero Negro      MX  27.9769 -114.0611     59.88        66
# 4            Viedma      AR -40.8135  -62.9967     60.89        61
# ..              ...     ...      ...       ...       ...       ...
# 692          Bereda      ES  43.2686   -7.5406     43.00        99
# 693            Kadi      IN  23.3000   72.3333     75.20        22
# 694      Kholmogory      RU  64.2229   41.6560     39.20        75
# 695         Malkara      TR  40.8900   26.9011     26.17        86
# 696      Phan Thiet      VN  10.9333  108.1000     82.22        66
#
#      Cloudiness  Wind Speed Current Description
# 0            22        1.01          light rain
# 1           100       25.10       moderate rain
# 2            72       18.81       broken clouds
# 3             0       14.79           clear sky
# 4           100       13.35     overcast clouds
# ..          ...         ...                 ...
# 692          84        1.99       broken clouds
# 693           5        6.91               smoke
# 694          20       11.18          few clouds
# 695          12        5.93          few clouds
# 696         100        8.81     overcast clouds
#
# [697 rows x 9 columns]

# %%
city_data_df.to_csv('Weather_Database/WeatherPy_Database.csv', index = False)
